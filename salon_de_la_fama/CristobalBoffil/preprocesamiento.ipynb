# %%
import pandas as pd
import numpy as np

pokemon_df = pd.read_csv("data/All_Pokemon.csv", delimiter=',')
pokemon_df = pokemon_df[['Number', 'Name', 'Type 1', 'Type 2', 'HP', 'Att', 'Def',
       'Spa', 'Spd', 'Spe', 'BST', 'Generation']]
pokemon_df['Name'] = pokemon_df['Name'].str.lower()
pokemon_df = pokemon_df[~pokemon_df.Name.str.contains("mega ")]
pokemon_df = pokemon_df[~pokemon_df.Name.str.contains("galarian")]
pokemon_df = pokemon_df[~pokemon_df.Name.str.contains("alolan")]
pokemon_df = pokemon_df[~pokemon_df.Name.str.contains("primal")]
pokemon_df = pokemon_df[~pokemon_df.Name.str.contains("deoxys attack")]
pokemon_df = pokemon_df[~pokemon_df.Name.str.contains("deoxys defense")]
pokemon_df = pokemon_df[~pokemon_df.Name.str.contains("deoxys speed")]
pokemon_df.loc[pokemon_df.Name.str.contains("deoxys"), "Name"] = "deoxys"

pokemon_df = pokemon_df[~pokemon_df.Name.str.contains("wormadam sandy")]
pokemon_df = pokemon_df[~pokemon_df.Name.str.contains("wormadam trash")]
pokemon_df.loc[pokemon_df.Name.str.contains("wormadam"), "Name"] = "wormadam"
pokemon_df.drop(pokemon_df.tail(2).index, inplace = True)
pokemon_df = pokemon_df[~pokemon_df.Name.str.contains("rotom-")]
pokemon_df = pokemon_df[~pokemon_df.Name.str.contains("giratina-")]
pokemon_df.loc[pokemon_df.Name.str.contains("giratina"), "Name"] = "giratina"

pokemon_df = pokemon_df[~pokemon_df.Name.str.contains("shaymin-")]
pokemon_df.loc[pokemon_df.Name.str.contains("shaymin"), "Name"] = "shaymin"

pokemon_df = pokemon_df[~pokemon_df.Name.str.contains("zen-mode")]
pokemon_df.loc[pokemon_df.Name.str.contains("darmanitan"), "Name"] = "darmanitan"

pokemon_df = pokemon_df[~pokemon_df.Name.str.contains("-therian")]
pokemon_df.loc[pokemon_df.Name.str.contains("thundurus"), "Name"] = "thundurus"
pokemon_df.loc[pokemon_df.Name.str.contains("tornadus"), "Name"] = "tornadus"
pokemon_df.loc[pokemon_df.Name.str.contains("landorus"), "Name"] = "landorus"


pokemon_df = pokemon_df[~pokemon_df.Name.str.contains("white kyurem")]
pokemon_df = pokemon_df[~pokemon_df.Name.str.contains("black kyurem")]
pokemon_df = pokemon_df[~pokemon_df.Name.str.contains("-pirouette")]
pokemon_df.loc[pokemon_df.Name.str.contains("meloetta"), "Name"] = "meloetta"
pokemon_df = pokemon_df[~pokemon_df.Name.str.contains("ash-")]
pokemon_df = pokemon_df[~pokemon_df.Name.str.contains("blade form")]

pokemon_df.loc[pokemon_df.Name.str.contains("aegislash"), "Name"] = "aegislash"

pokemon_df = pokemon_df[~pokemon_df.Name.str.contains("small size")]
pokemon_df = pokemon_df[~pokemon_df.Name.str.contains("large size")]
pokemon_df = pokemon_df[~pokemon_df.Name.str.contains("super size")]

pokemon_df.loc[pokemon_df.Name.str.contains("pumpkaboo"), "Name"] = "pumpkaboo"
pokemon_df.loc[pokemon_df.Name.str.contains("gourgeis"), "Name"] = "gourgeist"
pokemon_df = pokemon_df[~pokemon_df.Name.str.contains("complete")]
pokemon_df = pokemon_df[~pokemon_df.Name.str.contains("10%")]
pokemon_df = pokemon_df[~pokemon_df.Name.str.contains("unbound")]

pokemon_df = pokemon_df[~pokemon_df.Name.str.contains("pom-pom")]
pokemon_df = pokemon_df[~pokemon_df.Name.str.contains("pa'u")]
pokemon_df = pokemon_df[~pokemon_df.Name.str.contains("sensu")]
pokemon_df.loc[pokemon_df.Name.str.contains("oricorio"), "Name"] = "oricorio"

pokemon_df = pokemon_df[~pokemon_df.Name.str.contains("midnight")]
pokemon_df = pokemon_df[~pokemon_df.Name.str.contains(" dusk")]
pokemon_df.loc[pokemon_df.Name.str.contains("lycanroc"), "Name"] = "lycanroc"

pokemon_df = pokemon_df[~pokemon_df.Name.str.contains("school")]
pokemon_df.loc[pokemon_df.Name.str.contains("wishiwashi"), "Name"] = "wishiwashi"

pokemon_df = pokemon_df[~pokemon_df.Name.str.contains("minior core")]
pokemon_df.loc[pokemon_df.Name.str.contains("minior"), "Name"] = "minior"

pokemon_df = pokemon_df[~pokemon_df.Name.str.contains("dusk mane")]
pokemon_df = pokemon_df[~pokemon_df.Name.str.contains("dawn wings")]
pokemon_df = pokemon_df[~pokemon_df.Name.str.contains("ultra necrozma")]
pokemon_df = pokemon_df[~pokemon_df.Name.str.contains("crowned")]

pokemon_df.loc[pokemon_df.Name.str.contains("zacian"), "Name"] = "zacian"
pokemon_df.loc[pokemon_df.Name.str.contains("zamazenta"), "Name"] = "zamazenta"
pokemon_df = pokemon_df[~pokemon_df.Name.str.contains("rapid strike")]
pokemon_df.loc[pokemon_df.Name.str.contains("urshifu"), "Name"] = "urshifu"

pokemon_df = pokemon_df[~pokemon_df.Name.str.contains("noice face")]
pokemon_df.loc[pokemon_df.Name.str.contains("eiscue"), "Name"] = "eiscue-ice"
pokemon_df.to_csv('data/procesed_pkmn.csv',index=False)
pokemon_df[pokemon_df.Name.str.contains('nidoran')]
# Out:
#     Number      Name  Type 1 Type 2  HP  Att  Def  Spa  Spd  Spe  BST  \
# 39      29  nidoran♀  Poison    NaN  55   47   52   40   40   41  275
# 42      32  nidoran♂  Poison    NaN  46   57   40   40   40   50  273
#
#     Generation
# 39         1.0
# 42         1.0
